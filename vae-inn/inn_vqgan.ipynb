# %% [markdown]
# <a href="https://colab.research.google.com/github/bibisbar/vae-inn-synthesis-prober/blob/main/inn_vqgan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# WIKI:
#
# - INN module:https://github.com/ELIFE-ASU/INNLab/wiki
# - Latent diffusion:https://github.com/CompVis/latent-diffusion
# - ckpt of autoencoder:https://ommer-lab.com/files/latent-diffusion/kl-f8.zip or use [diffusers](https://huggingface.co/docs/diffusers/v0.3.0/en/api/models#diffusers.AutoencoderKL)
# - dataset [cifar100](https://pytorch.org/vision/stable/generated/torchvision.datasets.CIFAR100.html)

# %% [markdown]
# Tutorial of INN
#
# https://www.youtube.com/watch?v=IpbeIwSr7r0&ab_channel=PaulHand
#
# https://www.youtube.com/watch?v=WqP45Iyvd3o&ab_channel=heidelberg.ai

# %%
#@title Initialize INN and Autoencoder from VQGAN
# !git clone https://github.com/ELIFE-ASU/INNLab
# !git clone https://github.com/CompVis/taming-transformers
# %cd INNLab/
# !python setup.py install
# %cd ..
# Out:
# Cloning into 'INNLab'...
# remote: Enumerating objects: 830, done.
# remote: Counting objects: 100% (148/148), done.
# remote: Compressing objects: 100% (112/112), done.
# remote: Total 830 (delta 81), reused 71 (delta 35), pack-reused 682
# Receiving objects: 100% (830/830), 346.36 KiB | 5.59 MiB/s, done.
# Resolving deltas: 100% (492/492), done.
# Cloning into 'taming-transformers'...
# remote: Enumerating objects: 1342, done.
# remote: Counting objects: 100% (2/2), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 1342 (delta 0), reused 1 (delta 0), pack-reused 1340
# Receiving objects: 100% (1342/1342), 409.77 MiB | 14.20 MiB/s, done.
# Resolving deltas: 100% (282/282), done.
# /content/INNLab
# running install
# /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer, pypa/build or
#         other standards-based tools.
#
#         See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/cmd.py:66: EasyInstallDeprecationWarning: easy_install command is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` and ``easy_install``.
#         Instead, use pypa/build, pypa/installer, pypa/build or
#         other standards-based tools.
#
#         See https://github.com/pypa/setuptools/issues/917 for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# running bdist_egg
# running egg_info
# creating INNLab.egg-info
# writing INNLab.egg-info/PKG-INFO
# writing dependency_links to INNLab.egg-info/dependency_links.txt
# writing top-level names to INNLab.egg-info/top_level.txt
# writing manifest file 'INNLab.egg-info/SOURCES.txt'
# reading manifest file 'INNLab.egg-info/SOURCES.txt'
# adding license file 'LICENSE'
# writing manifest file 'INNLab.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build
# creating build/lib
# creating build/lib/INN
# copying INN/Sequential.py -> build/lib/INN
# copying INN/__init__.py -> build/lib/INN
# copying INN/utilities.py -> build/lib/INN
# copying INN/INNAbstract.py -> build/lib/INN
# copying INN/pixel_shuffle_1d.py -> build/lib/INN
# copying INN/INN.py -> build/lib/INN
# copying INN/BatchNorm.py -> build/lib/INN
# creating build/lib/INN/ResFlow
# copying INN/ResFlow/SpectralNormGouk.py -> build/lib/INN/ResFlow
# copying INN/ResFlow/ResidualFlow.py -> build/lib/INN/ResFlow
# copying INN/ResFlow/BackwardInForward.py -> build/lib/INN/ResFlow
# copying INN/ResFlow/__init__.py -> build/lib/INN/ResFlow
# copying INN/ResFlow/utilities.py -> build/lib/INN/ResFlow
# copying INN/ResFlow/ResidualFlowBlocks.py -> build/lib/INN/ResFlow
# creating build/lib/INN/CouplingModels
# creating build/lib/INN/CouplingModels/NICEModel
# copying INN/CouplingModels/NICEModel/conv.py -> build/lib/INN/CouplingModels/NICEModel
# copying INN/CouplingModels/NICEModel/__init__.py -> build/lib/INN/CouplingModels/NICEModel
# copying INN/CouplingModels/NICEModel/utils.py -> build/lib/INN/CouplingModels/NICEModel
# copying INN/CouplingModels/NICEModel/nice_linear.py -> build/lib/INN/CouplingModels/NICEModel
# copying INN/CouplingModels/NICEModel/NICE_base.py -> build/lib/INN/CouplingModels/NICEModel
# creating build/lib/INN/CouplingModels/RealNVP
# copying INN/CouplingModels/RealNVP/conv.py -> build/lib/INN/CouplingModels/RealNVP
# copying INN/CouplingModels/RealNVP/conv1d.py -> build/lib/INN/CouplingModels/RealNVP
# copying INN/CouplingModels/RealNVP/__init__.py -> build/lib/INN/CouplingModels/RealNVP
# copying INN/CouplingModels/RealNVP/conv2d.py -> build/lib/INN/CouplingModels/RealNVP
# copying INN/CouplingModels/RealNVP/linear.py -> build/lib/INN/CouplingModels/RealNVP
# copying INN/CouplingModels/RealNVP/utils.py -> build/lib/INN/CouplingModels/RealNVP
# copying INN/CouplingModels/conv.py -> build/lib/INN/CouplingModels
# copying INN/CouplingModels/__init__.py -> build/lib/INN/CouplingModels
# copying INN/CouplingModels/utils.py -> build/lib/INN/CouplingModels
# creating build/lib/INN/Linears
# copying INN/Linears/jacobian_linear.py -> build/lib/INN/Linears
# copying INN/Linears/__init__.py -> build/lib/INN/Linears
# creating build/lib/INN/EUNN
# copying INN/EUNN/funtional.py -> build/lib/INN/EUNN
# copying INN/EUNN/__init__.py -> build/lib/INN/EUNN
# copying INN/EUNN/eunn.py -> build/lib/INN/EUNN
# creating build/bdist.linux-x86_64
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/INN
# creating build/bdist.linux-x86_64/egg/INN/Linears
# copying build/lib/INN/Linears/jacobian_linear.py -> build/bdist.linux-x86_64/egg/INN/Linears
# copying build/lib/INN/Linears/__init__.py -> build/bdist.linux-x86_64/egg/INN/Linears
# copying build/lib/INN/Sequential.py -> build/bdist.linux-x86_64/egg/INN
# creating build/bdist.linux-x86_64/egg/INN/CouplingModels
# copying build/lib/INN/CouplingModels/conv.py -> build/bdist.linux-x86_64/egg/INN/CouplingModels
# creating build/bdist.linux-x86_64/egg/INN/CouplingModels/NICEModel
# copying build/lib/INN/CouplingModels/NICEModel/conv.py -> build/bdist.linux-x86_64/egg/INN/CouplingModels/NICEModel
# copying build/lib/INN/CouplingModels/NICEModel/__init__.py -> build/bdist.linux-x86_64/egg/INN/CouplingModels/NICEModel
# copying build/lib/INN/CouplingModels/NICEModel/utils.py -> build/bdist.linux-x86_64/egg/INN/CouplingModels/NICEModel
# copying build/lib/INN/CouplingModels/NICEModel/nice_linear.py -> build/bdist.linux-x86_64/egg/INN/CouplingModels/NICEModel
# copying build/lib/INN/CouplingModels/NICEModel/NICE_base.py -> build/bdist.linux-x86_64/egg/INN/CouplingModels/NICEModel
# copying build/lib/INN/CouplingModels/__init__.py -> build/bdist.linux-x86_64/egg/INN/CouplingModels
# copying build/lib/INN/CouplingModels/utils.py -> build/bdist.linux-x86_64/egg/INN/CouplingModels
# creating build/bdist.linux-x86_64/egg/INN/CouplingModels/RealNVP
# copying build/lib/INN/CouplingModels/RealNVP/conv.py -> build/bdist.linux-x86_64/egg/INN/CouplingModels/RealNVP
# copying build/lib/INN/CouplingModels/RealNVP/conv1d.py -> build/bdist.linux-x86_64/egg/INN/CouplingModels/RealNVP
# copying build/lib/INN/CouplingModels/RealNVP/__init__.py -> build/bdist.linux-x86_64/egg/INN/CouplingModels/RealNVP
# copying build/lib/INN/CouplingModels/RealNVP/conv2d.py -> build/bdist.linux-x86_64/egg/INN/CouplingModels/RealNVP
# copying build/lib/INN/CouplingModels/RealNVP/linear.py -> build/bdist.linux-x86_64/egg/INN/CouplingModels/RealNVP
# copying build/lib/INN/CouplingModels/RealNVP/utils.py -> build/bdist.linux-x86_64/egg/INN/CouplingModels/RealNVP
# copying build/lib/INN/__init__.py -> build/bdist.linux-x86_64/egg/INN
# copying build/lib/INN/utilities.py -> build/bdist.linux-x86_64/egg/INN
# copying build/lib/INN/INNAbstract.py -> build/bdist.linux-x86_64/egg/INN
# creating build/bdist.linux-x86_64/egg/INN/EUNN
# copying build/lib/INN/EUNN/funtional.py -> build/bdist.linux-x86_64/egg/INN/EUNN
# copying build/lib/INN/EUNN/__init__.py -> build/bdist.linux-x86_64/egg/INN/EUNN
# copying build/lib/INN/EUNN/eunn.py -> build/bdist.linux-x86_64/egg/INN/EUNN
# copying build/lib/INN/pixel_shuffle_1d.py -> build/bdist.linux-x86_64/egg/INN
# copying build/lib/INN/INN.py -> build/bdist.linux-x86_64/egg/INN
# copying build/lib/INN/BatchNorm.py -> build/bdist.linux-x86_64/egg/INN
# creating build/bdist.linux-x86_64/egg/INN/ResFlow
# copying build/lib/INN/ResFlow/SpectralNormGouk.py -> build/bdist.linux-x86_64/egg/INN/ResFlow
# copying build/lib/INN/ResFlow/ResidualFlow.py -> build/bdist.linux-x86_64/egg/INN/ResFlow
# copying build/lib/INN/ResFlow/BackwardInForward.py -> build/bdist.linux-x86_64/egg/INN/ResFlow
# copying build/lib/INN/ResFlow/__init__.py -> build/bdist.linux-x86_64/egg/INN/ResFlow
# copying build/lib/INN/ResFlow/utilities.py -> build/bdist.linux-x86_64/egg/INN/ResFlow
# copying build/lib/INN/ResFlow/ResidualFlowBlocks.py -> build/bdist.linux-x86_64/egg/INN/ResFlow
# byte-compiling build/bdist.linux-x86_64/egg/INN/Linears/jacobian_linear.py to jacobian_linear.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/INN/Linears/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/INN/Sequential.py to Sequential.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/INN/CouplingModels/conv.py to conv.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/INN/CouplingModels/NICEModel/conv.py to conv.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/INN/CouplingModels/NICEModel/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/INN/CouplingModels/NICEModel/utils.py to utils.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/INN/CouplingModels/NICEModel/nice_linear.py to nice_linear.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/INN/CouplingModels/NICEModel/NICE_base.py to NICE_base.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/INN/CouplingModels/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/INN/CouplingModels/utils.py to utils.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/INN/CouplingModels/RealNVP/conv.py to conv.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/INN/CouplingModels/RealNVP/conv1d.py to conv1d.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/INN/CouplingModels/RealNVP/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/INN/CouplingModels/RealNVP/conv2d.py to conv2d.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/INN/CouplingModels/RealNVP/linear.py to linear.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/INN/CouplingModels/RealNVP/utils.py to utils.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/INN/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/INN/utilities.py to utilities.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/INN/INNAbstract.py to INNAbstract.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/INN/EUNN/funtional.py to funtional.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/INN/EUNN/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/INN/EUNN/eunn.py to eunn.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/INN/pixel_shuffle_1d.py to pixel_shuffle_1d.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/INN/INN.py to INN.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/INN/BatchNorm.py to BatchNorm.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/INN/ResFlow/SpectralNormGouk.py to SpectralNormGouk.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/INN/ResFlow/ResidualFlow.py to ResidualFlow.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/INN/ResFlow/BackwardInForward.py to BackwardInForward.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/INN/ResFlow/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/INN/ResFlow/utilities.py to utilities.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/INN/ResFlow/ResidualFlowBlocks.py to ResidualFlowBlocks.cpython-310.pyc
# creating build/bdist.linux-x86_64/egg/EGG-INFO
# copying INNLab.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying INNLab.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying INNLab.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying INNLab.egg-info/top_level.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# zip_safe flag not set; analyzing archive contents...
# creating dist
# creating 'dist/INNLab-0.9.0-py3.10.egg' and adding 'build/bdist.linux-x86_64/egg' to it
# removing 'build/bdist.linux-x86_64/egg' (and everything under it)
# Processing INNLab-0.9.0-py3.10.egg
# Copying INNLab-0.9.0-py3.10.egg to /usr/local/lib/python3.10/dist-packages
# Adding INNLab 0.9.0 to easy-install.pth file
#
# Installed /usr/local/lib/python3.10/dist-packages/INNLab-0.9.0-py3.10.egg
# Processing dependencies for INNLab==0.9.0
# Finished processing dependencies for INNLab==0.9.0
# /content

# %%
#@title Environment
# !pip install --upgrade diffusers transformers scipy pytorch-lightning
# !pip install omegaconf>=2.0.0 torch==1.13.1 torchvision torchdata torchtext pytorch-lightning>=1.0.8 einops>=0.3.0 accelerate normflows
# !pip uninstall -y torchaudio
# Out:
# Collecting diffusers
#   Downloading diffusers-0.18.2-py3-none-any.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 23.0 MB/s eta 0:00:00
# Collecting transformers
#   Downloading transformers-4.30.2-py3-none-any.whl (7.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 73.4 MB/s eta 0:00:00
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (1.10.1)
# Collecting scipy
#   Downloading scipy-1.11.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (36.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.3/36.3 MB 44.8 MB/s eta 0:00:00
# Collecting pytorch-lightning
#   Downloading pytorch_lightning-2.0.5-py3-none-any.whl (722 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 722.4/722.4 kB 60.9 MB/s eta 0:00:00
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from diffusers) (8.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from diffusers) (3.12.2)
# Collecting huggingface-hub>=0.13.2 (from diffusers)
#   Downloading huggingface_hub-0.16.4-py3-none-any.whl (268 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 34.7 MB/s eta 0:00:00
# Collecting importlib-metadata (from diffusers)
#   Downloading importlib_metadata-6.8.0-py3-none-any.whl (22 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from diffusers) (1.22.4)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from diffusers) (2022.10.31)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from diffusers) (2.27.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 122.1 MB/s eta 0:00:00
# Collecting safetensors>=0.3.1 (from transformers)
#   Downloading safetensors-0.3.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 82.1 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning) (2.0.1+cu118)
# Requirement already satisfied: fsspec[http]>2021.06.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning) (2023.6.0)
# Collecting torchmetrics>=0.7.0 (from pytorch-lightning)
#   Downloading torchmetrics-1.0.1-py3-none-any.whl (729 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 729.2/729.2 kB 64.6 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning) (4.7.1)
# Collecting lightning-utilities>=0.7.0 (from pytorch-lightning)
#   Downloading lightning_utilities-0.9.0-py3-none-any.whl (23 kB)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]>2021.06.0->pytorch-lightning) (3.8.4)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->pytorch-lightning) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->pytorch-lightning) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->pytorch-lightning) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->pytorch-lightning) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.11.0->pytorch-lightning) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.11.0->pytorch-lightning) (16.0.6)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata->diffusers) (3.16.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->diffusers) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->diffusers) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->diffusers) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->diffusers) (3.4)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11.0->pytorch-lightning) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.11.0->pytorch-lightning) (1.3.0)
# Installing collected packages: tokenizers, safetensors, scipy, lightning-utilities, importlib-metadata, huggingface-hub, transformers, diffusers, torchmetrics, pytorch-lightning
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.10.1
#     Uninstalling scipy-1.10.1:
#       Successfully uninstalled scipy-1.10.1
# Successfully installed diffusers-0.18.2 huggingface-hub-0.16.4 importlib-metadata-6.8.0 lightning-utilities-0.9.0 pytorch-lightning-2.0.5 safetensors-0.3.1 scipy-1.11.1 tokenizers-0.13.3 torchmetrics-1.0.1 transformers-4.30.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.0.2+cu118 requires torch==2.0.1, but you have torch 1.13.1 which is incompatible.
# Found existing installation: torchaudio 2.0.2+cu118
# Uninstalling torchaudio-2.0.2+cu118:
#   Successfully uninstalled torchaudio-2.0.2+cu118

# %%
import sys
sys.path.append(".")

# also disable grad to save memory
import torch
torch.set_grad_enabled(False)

DEVICE = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
# !git clone https://github.com/ELIFE-ASU/INNLab
# %cd INNLab/
# !python setup.py install
import INN
# Out:
# fatal: destination path 'INNLab' already exists and is not an empty directory.
# /content/INNLab
# running install
# /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer, pypa/build or
#         other standards-based tools.
#
#         See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/cmd.py:66: EasyInstallDeprecationWarning: easy_install command is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` and ``easy_install``.
#         Instead, use pypa/build, pypa/installer, pypa/build or
#         other standards-based tools.
#
#         See https://github.com/pypa/setuptools/issues/917 for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# running bdist_egg
# running egg_info
# writing INNLab.egg-info/PKG-INFO
# writing dependency_links to INNLab.egg-info/dependency_links.txt
# writing top-level names to INNLab.egg-info/top_level.txt
# reading manifest file 'INNLab.egg-info/SOURCES.txt'
# adding license file 'LICENSE'
# writing manifest file 'INNLab.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/INN
# creating build/bdist.linux-x86_64/egg/INN/Linears
# copying build/lib/INN/Linears/jacobian_linear.py -> build/bdist.linux-x86_64/egg/INN/Linears
# copying build/lib/INN/Linears/__init__.py -> build/bdist.linux-x86_64/egg/INN/Linears
# copying build/lib/INN/Sequential.py -> build/bdist.linux-x86_64/egg/INN
# creating build/bdist.linux-x86_64/egg/INN/CouplingModels
# copying build/lib/INN/CouplingModels/conv.py -> build/bdist.linux-x86_64/egg/INN/CouplingModels
# creating build/bdist.linux-x86_64/egg/INN/CouplingModels/NICEModel
# copying build/lib/INN/CouplingModels/NICEModel/conv.py -> build/bdist.linux-x86_64/egg/INN/CouplingModels/NICEModel
# copying build/lib/INN/CouplingModels/NICEModel/__init__.py -> build/bdist.linux-x86_64/egg/INN/CouplingModels/NICEModel
# copying build/lib/INN/CouplingModels/NICEModel/utils.py -> build/bdist.linux-x86_64/egg/INN/CouplingModels/NICEModel
# copying build/lib/INN/CouplingModels/NICEModel/nice_linear.py -> build/bdist.linux-x86_64/egg/INN/CouplingModels/NICEModel
# copying build/lib/INN/CouplingModels/NICEModel/NICE_base.py -> build/bdist.linux-x86_64/egg/INN/CouplingModels/NICEModel
# copying build/lib/INN/CouplingModels/__init__.py -> build/bdist.linux-x86_64/egg/INN/CouplingModels
# copying build/lib/INN/CouplingModels/utils.py -> build/bdist.linux-x86_64/egg/INN/CouplingModels
# creating build/bdist.linux-x86_64/egg/INN/CouplingModels/RealNVP
# copying build/lib/INN/CouplingModels/RealNVP/conv.py -> build/bdist.linux-x86_64/egg/INN/CouplingModels/RealNVP
# copying build/lib/INN/CouplingModels/RealNVP/conv1d.py -> build/bdist.linux-x86_64/egg/INN/CouplingModels/RealNVP
# copying build/lib/INN/CouplingModels/RealNVP/__init__.py -> build/bdist.linux-x86_64/egg/INN/CouplingModels/RealNVP
# copying build/lib/INN/CouplingModels/RealNVP/conv2d.py -> build/bdist.linux-x86_64/egg/INN/CouplingModels/RealNVP
# copying build/lib/INN/CouplingModels/RealNVP/linear.py -> build/bdist.linux-x86_64/egg/INN/CouplingModels/RealNVP
# copying build/lib/INN/CouplingModels/RealNVP/utils.py -> build/bdist.linux-x86_64/egg/INN/CouplingModels/RealNVP
# copying build/lib/INN/__init__.py -> build/bdist.linux-x86_64/egg/INN
# copying build/lib/INN/utilities.py -> build/bdist.linux-x86_64/egg/INN
# copying build/lib/INN/INNAbstract.py -> build/bdist.linux-x86_64/egg/INN
# creating build/bdist.linux-x86_64/egg/INN/EUNN
# copying build/lib/INN/EUNN/funtional.py -> build/bdist.linux-x86_64/egg/INN/EUNN
# copying build/lib/INN/EUNN/__init__.py -> build/bdist.linux-x86_64/egg/INN/EUNN
# copying build/lib/INN/EUNN/eunn.py -> build/bdist.linux-x86_64/egg/INN/EUNN
# copying build/lib/INN/pixel_shuffle_1d.py -> build/bdist.linux-x86_64/egg/INN
# copying build/lib/INN/INN.py -> build/bdist.linux-x86_64/egg/INN
# copying build/lib/INN/BatchNorm.py -> build/bdist.linux-x86_64/egg/INN
# creating build/bdist.linux-x86_64/egg/INN/ResFlow
# copying build/lib/INN/ResFlow/SpectralNormGouk.py -> build/bdist.linux-x86_64/egg/INN/ResFlow
# copying build/lib/INN/ResFlow/ResidualFlow.py -> build/bdist.linux-x86_64/egg/INN/ResFlow
# copying build/lib/INN/ResFlow/BackwardInForward.py -> build/bdist.linux-x86_64/egg/INN/ResFlow
# copying build/lib/INN/ResFlow/__init__.py -> build/bdist.linux-x86_64/egg/INN/ResFlow
# copying build/lib/INN/ResFlow/utilities.py -> build/bdist.linux-x86_64/egg/INN/ResFlow
# copying build/lib/INN/ResFlow/ResidualFlowBlocks.py -> build/bdist.linux-x86_64/egg/INN/ResFlow
# byte-compiling build/bdist.linux-x86_64/egg/INN/Linears/jacobian_linear.py to jacobian_linear.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/INN/Linears/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/INN/Sequential.py to Sequential.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/INN/CouplingModels/conv.py to conv.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/INN/CouplingModels/NICEModel/conv.py to conv.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/INN/CouplingModels/NICEModel/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/INN/CouplingModels/NICEModel/utils.py to utils.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/INN/CouplingModels/NICEModel/nice_linear.py to nice_linear.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/INN/CouplingModels/NICEModel/NICE_base.py to NICE_base.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/INN/CouplingModels/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/INN/CouplingModels/utils.py to utils.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/INN/CouplingModels/RealNVP/conv.py to conv.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/INN/CouplingModels/RealNVP/conv1d.py to conv1d.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/INN/CouplingModels/RealNVP/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/INN/CouplingModels/RealNVP/conv2d.py to conv2d.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/INN/CouplingModels/RealNVP/linear.py to linear.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/INN/CouplingModels/RealNVP/utils.py to utils.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/INN/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/INN/utilities.py to utilities.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/INN/INNAbstract.py to INNAbstract.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/INN/EUNN/funtional.py to funtional.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/INN/EUNN/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/INN/EUNN/eunn.py to eunn.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/INN/pixel_shuffle_1d.py to pixel_shuffle_1d.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/INN/INN.py to INN.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/INN/BatchNorm.py to BatchNorm.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/INN/ResFlow/SpectralNormGouk.py to SpectralNormGouk.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/INN/ResFlow/ResidualFlow.py to ResidualFlow.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/INN/ResFlow/BackwardInForward.py to BackwardInForward.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/INN/ResFlow/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/INN/ResFlow/utilities.py to utilities.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/INN/ResFlow/ResidualFlowBlocks.py to ResidualFlowBlocks.cpython-310.pyc
# creating build/bdist.linux-x86_64/egg/EGG-INFO
# copying INNLab.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying INNLab.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying INNLab.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying INNLab.egg-info/top_level.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# zip_safe flag not set; analyzing archive contents...
# creating 'dist/INNLab-0.9.0-py3.10.egg' and adding 'build/bdist.linux-x86_64/egg' to it
# removing 'build/bdist.linux-x86_64/egg' (and everything under it)
# Processing INNLab-0.9.0-py3.10.egg
# Removing /usr/local/lib/python3.10/dist-packages/INNLab-0.9.0-py3.10.egg
# Copying INNLab-0.9.0-py3.10.egg to /usr/local/lib/python3.10/dist-packages
# INNLab 0.9.0 is already the active version in easy-install.pth
#
# Installed /usr/local/lib/python3.10/dist-packages/INNLab-0.9.0-py3.10.egg
# Processing dependencies for INNLab==0.9.0
# Finished processing dependencies for INNLab==0.9.0

# %% [markdown]
# # Stable Diffusion Encoder/Decoder

# %% [markdown]
# ##### Sample Encoding/Decoding

# %%
# !pip install diffusers
from diffusers.models import AutoencoderKL
from diffusers import StableDiffusionPipeline
import torch

# Initialize the VAE of Stable Diffusion model using the pretrained weights.
# TODO: use the encoder and decoder of sd, not vq
sd_vae = AutoencoderKL.from_pretrained("stabilityai/sd-vae-ft-mse").to(DEVICE)
sd_vae.eval()

img = torch.randn(size=(1,3,32,32)).to(DEVICE)
latent_output = sd_vae.tiled_encode(x=img)

#encoder = sd_vae.encoder.to(DEVICE)
#encoder.eval() # Turn on evaluation mode
#latent = encoder(img)
#encoder
#latent.shape

decoded_output = sd_vae.tiled_decode(z=latent_output.latent_dist.sample())

#model = "CompVis/stable-diffusion-v1-4"
#pipe = StableDiffusionPipeline.from_pretrained(model, vae=vae)
#pipe = pipe.to("cuda")

# %%
latent_output.latent_dist.sample().shape
# Out:
# torch.Size([1, 4, 4, 4])

# %%
decoded_output.sample.shape
# Out:
# torch.Size([1, 3, 32, 32])

# %%
from numpy.core.fromnumeric import var
import pytorch_lightning as pl
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
import torchvision
from torchvision import datasets
from torchvision.transforms import ToTensor, Compose, Normalize
import numpy as np
import INN

transform = Compose(
    [ToTensor(),
     Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

train_set = datasets.CIFAR100(root='data', train=True,
                              download=True, transform=transform)
val_set = datasets.CIFAR100(root='data', train=False,
                              download=True, transform=transform)

class VariationalEncoder(pl.LightningModule):
    def __init__(self):
        super().__init__()
        self.sd_vae = AutoencoderKL.from_pretrained("stabilityai/sd-vae-ft-mse")
        self.sd_vae.eval()
    def forward(self,x):
        latent_output = sd_vae.tiled_encode(x)
        return latent_output.latent_dist.sample()

class InnModel(pl.LightningModule):
    def __init__(self) :
        super().__init__()
        self.latent_dim = 2
        self.mu = INN.Sequential(INN.Nonlinear(64, 'RealNVP', k=self.latent_dim), INN.Nonlinear(64, 'RealNVP', k=self.latent_dim))
        self.sigma = INN.Sequential(INN.Nonlinear(64, 'RealNVP', k=self.latent_dim), INN.Nonlinear(64, 'RealNVP', k=self.latent_dim))
        self.relu = nn.ReLU()
        self.sig = nn.Sigmoid()
    def forward(self,x):
        mean_out, _, _ = self.mu(x)
        var_out, _, _ = self.sigma(x)
        return self.sig(mean_out) , self.sig(var_out)

class VaeInnModel(pl.LightningModule):
    def __init__(self) :
        super().__init__()
        self.sd_vae = AutoencoderKL.from_pretrained("stabilityai/sd-vae-ft-mse")
        #self.sd_vae.eval()
        self.BATCH_SIZE = 8
        #Magic number
        self.scale_factor = 0.18215
        # Initialize three parts
        self.encoder = VariationalEncoder()
        self.flatten = nn.Flatten()
        self.innmodule = InnModel()

        # Initialize a 'target' normal distribution for KL divergence
        self.norm = torch.distributions.Normal(0, 1)
    def forward(self, x):
        z_sample = self.encoder(x)
        z_flatten = self.flatten(z_sample*self.scale_factor)
        mean_flatten,var_flatten = self.innmodule(z_flatten)
        mean_sample = mean_flatten.reshape(z_sample.shape)
        var_sample = var_flatten.reshape(z_sample.shape)

        #Get sample from norm distribution
        norm_sample = self.norm.sample(mean_sample.shape).to(DEVICE)

        #Reparalization
        inn_sample =  var_sample * norm_sample + mean_sample

        return inn_sample, mean_sample, var_sample

    def training_step(self, batch, batch_idx):
        image, label = batch
        latent_output, mean , var = self(image)

        #image_rec = sd_vae.tiled_decode(latent_output).sample

        #Compute kl loss
        kl_loss = (0.5 * (var ** 2) + 0.5 * (mean ** 2) - torch.log(var) - 0.5).sum()
        self.log("train_kl_loss", kl_loss)
        #Compute reconstruction loss
        #rec_loss = ((image - image_rec)**2).sum()
        #self.log("train_rec_loss", rec_loss)
        #loss = kl_loss + rec_loss
        loss = kl_loss  #remove rec loss
        #Logs
        self.log("train_total_loss", loss)
        print(loss)
        return loss

    def validation_step(self, batch, batch_idx):
        image, label = batch
        latent_output, mean , var = self(image)

        #image_rec = sd_vae.tiled_decode(latent_output).sample

        #Compute kl loss
        kl_loss = (0.5 * (var ** 2) + 0.5 * (mean ** 2) - torch.log(var) - 0.5).sum()
        self.log("val_kl_loss", kl_loss)
        #Compute reconstruction loss
        #rec_loss = ((image - image_rec)**2).sum()
        #self.log("val_rec_loss", rec_loss)
        #loss = kl_loss + rec_loss
        loss = kl_loss  #remove rec loss
        #Logs
        self.log("val_total_loss", loss)
        return loss

    def test_step(self, batch, batch_idx):
        image, label = batch
        latent_output, mean , var = self(image)

        #image_rec = sd_vae.tiled_decode(latent_output).sample

        #Compute kl loss
        kl_loss = (0.5 * (var ** 2) + 0.5 * (mean ** 2) - torch.log(var) - 0.5).sum()
        self.log("test_kl_loss", kl_loss)
        #Compute reconstruction loss
        #rec_loss = ((image - image_rec)**2).sum()
        #self.log("test_rec_loss", rec_loss)
        #loss = kl_loss + rec_loss
        loss = kl_loss  #remove rec loss
        #Logs
        self.log("test_total_loss", loss)
        return loss

    def configure_optimizers(self):
        optimizer = optim.Adam(self.parameters(), lr=0.001)
        return optimizer

# Example usage
# Assuming you have train_dataset and val_dataset as torch.utils.data.Dataset objects

model = VaeInnModel()
train_loader = DataLoader(train_set, batch_size=model.BATCH_SIZE, shuffle=True)
val_loader = DataLoader(val_set, batch_size=model.BATCH_SIZE)

if DEVICE == 'cpu':
  devices = 0
else:
  devices = 1
trainer = pl.Trainer(max_epochs=1, devices=devices)  # Set devices=1 for GPU training

# Start training
trainer.fit(model, train_dataloaders=train_loader, val_dataloaders=val_loader)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name      | Type               | Params
# -------------------------------------------------
# 0 | sd_vae    | AutoencoderKL      | 83.7 M
# 1 | encoder   | VariationalEncoder | 83.7 M
# 2 | flatten   | Flatten            | 0
# 3 | innmodule | InnModel           | 264 K
# -------------------------------------------------
# 167 M     Trainable params
# 0         Non-trainable params
# 167 M     Total params
# 670.290   Total estimated model params size (MB)
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# tensor(281.3767, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(271.3380, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(268.3920, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(254.6314, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(229.4486, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(240.4151, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(248.7822, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(208.9075, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(158.0862, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(193.4676, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(154.0646, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(218.3093, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(147.3857, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(149.2990, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(90.0163, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(71.6158, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(157.1087, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(67.9785, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(36.0986, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(30.8340, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(15.2910, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(13.4528, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(39.2563, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(17.2626, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(46.2586, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(4.0961, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(11.9676, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(8.6498, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.9451, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(1.0893, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(6.2807, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(1.1483, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.2107, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.3851, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(1.0170, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.5510, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.8448, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0660, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.1868, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0468, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.6164, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0540, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0453, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0197, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.2593, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0692, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0382, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0200, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0353, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0160, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0561, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.1769, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0120, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0095, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0074, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0195, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0091, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0072, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0057, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0389, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0163, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0155, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0074, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0138, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0063, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0039, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0090, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0066, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0054, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0157, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0985, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0099, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0130, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0031, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0076, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0193, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0045, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0284, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0054, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0294, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0131, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0072, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0038, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0073, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0083, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0083, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.4591, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0046, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0155, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0216, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0046, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0099, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0624, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0058, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0092, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(3.5717, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0268, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0061, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0046, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0079, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0024, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0044, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0110, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0102, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0042, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0037, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0052, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0416, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0025, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0078, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0070, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0033, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0024, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0034, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.3131, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0259, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0044, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0081, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0040, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0217, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0021, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(10.0136, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0036, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(2.2891, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0210, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0069, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0921, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0307, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0050, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0046, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0206, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0043, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0061, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.9988, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0026, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0295, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(1.2405, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0058, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0408, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0353, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0082, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0036, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0098, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0098, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0022, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0029, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0018, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.3566, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0029, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0137, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0208, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0046, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.6830, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0029, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0058, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(3.4798, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(1.1342, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.1049, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0451, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0324, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0063, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0031, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.2504, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0032, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0030, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0040, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0364, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0138, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0861, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0071, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0023, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0034, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0021, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0030, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0047, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0143, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0055, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0039, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0021, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0009, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.1051, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0018, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0035, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0159, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0031, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0016, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0035, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0027, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0011, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0018, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0014, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0016, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0399, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0027, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0020, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0035, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0018, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0065, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0015, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0016, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0020, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(2.9472, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0380, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0036, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0011, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0010, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0030, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0039, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0015, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0019, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0021, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0046, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0013, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0017, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0061, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0015, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0015, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0009, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0059, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0018, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.1778, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.8594, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0011, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0008, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0017, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0046, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0115, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0183, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0018, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0013, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0020, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0016, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0020, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0009, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0015, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0037, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0012, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0017, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0031, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0190, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0024, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0061, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0012, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0068, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.1338, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(159.3401, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0034, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0054, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0096, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0218, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0477, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.1118, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(191.3905, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.7368, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(1.7659, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(5.9041, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(5.3688, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(2.8857, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(3.9325, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(6.6485, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(2.1451, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(8.4055, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(2.3476, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.6540, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(3.1797, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.6140, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.9487, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(1.8760, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.8235, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.4312, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.6016, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.5894, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.3216, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.2085, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.3495, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.1205, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.3191, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.5221, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.1591, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.1113, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0394, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0738, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0660, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.3749, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0381, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0602, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.2221, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0452, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0361, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0324, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0427, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0406, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0244, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0702, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0353, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0369, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0261, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.6622, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.5269, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0259, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.1208, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0467, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0192, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0184, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0136, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0177, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.1165, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0140, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0096, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0346, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0723, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0167, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0155, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0604, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0419, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0126, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0120, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0533, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0295, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0094, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0125, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0078, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0096, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.1605, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0078, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0129, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0061, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0075, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0396, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.1063, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0091, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0114, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0098, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0050, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0829, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0158, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0196, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0092, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0077, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0099, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0137, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0118, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.1124, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0118, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0083, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0076, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.2747, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0529, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0169, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0307, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0028, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0297, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0085, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0058, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0048, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0044, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0078, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0045, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0079, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0099, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0020, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0072, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0258, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0066, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0032, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0187, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0142, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0101, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0063, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0043, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0036, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0049, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0184, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0075, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0067, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0051, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0040, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0075, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0060, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0023, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0101, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0232, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0065, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0023, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0036, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0026, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0385, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0041, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0064, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0027, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0017, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0015, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0155, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0029, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0018, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0817, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0144, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0055, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0023, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0019, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0188, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0023, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.3617, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0023, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0037, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0030, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0770, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0098, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0063, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0036, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0029, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0106, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0041, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0030, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0096, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.5065, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0034, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0026, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0023, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0119, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0020, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0015, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0041, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0021, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0379, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0106, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0025, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0018, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0036, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0018, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0153, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0008, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0057, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0019, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0160, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0062, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0017, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0013, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0019, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0026, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0019, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0032, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0154, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0009, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0038, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0018, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0024, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0029, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0045, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0018, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0026, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0032, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0008, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0340, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0013, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0126, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0027, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0027, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0008, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0018, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0016, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0043, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0013, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0012, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0010, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0026, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0080, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0032, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0053, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0024, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0038, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0028, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0011, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0016, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0015, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0014, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0447, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0032, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0012, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0052, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0010, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0015, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0026, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0029, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0016, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0018, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0011, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.1914, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0010, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0015, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0034, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0038, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0013, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0009, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0024, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0046, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0014, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0123, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0030, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0005, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0020, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0009, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0014, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0029, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0020, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0477, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0054, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0009, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0027, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0059, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0023, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0032, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0025, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0048, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0012, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0014, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0011, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0062, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0112, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0253, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0011, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0009, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0021, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0011, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0042, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0018, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0142, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0041, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0009, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0015, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0043, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0018, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0015, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0069, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0078, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0193, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0038, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0013, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0007, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0022, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0096, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0179, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0021, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0014, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0008, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0021, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0048, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0007, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0050, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0024, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0013, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0009, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0041, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0007, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0027, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0019, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0006, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0036, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0006, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0011, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0016, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0014, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0215, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0036, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0033, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0024, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0017, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0011, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0008, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0007, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0009, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0029, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0131, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0008, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0012, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0008, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0012, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0010, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0005, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0060, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0016, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0185, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0032, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0008, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0008, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0008, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0015, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0004, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0006, device='cuda:0', grad_fn=<SumBackward0>)
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/trainer/call.py:52: UserWarning: Detected KeyboardInterrupt, attempting graceful shutdown...
#   rank_zero_warn("Detected KeyboardInterrupt, attempting graceful shutdown...")

# %% [markdown]
# # Invertible NNs Tutorial

# %%
import INN
import torch.nn as nn
import torch.utils.data as data
import torch.optim as optim

import numpy as np

# %%
class half_circle(data.Dataset):
    r'''Generate a dataset of points on a half circle.'''
    def __init__(self, n=512):
        super(half_circle, self).__init__()
        self.n = n

    def __getitem__(self, index):
        r = 1.0
        phi = torch.rand(1) * torch.pi
        x = torch.cos(phi) * r
        y = torch.sin(phi) * r
        return torch.cat((x, y), 0) + torch.randn(2) / 20

    def __len__(self):
        return self.n

# %%
# Plot dataset points
import matplotlib.pyplot as plt

sampled = np.array([half_circle()[0].tolist() for i in range(500)])
plt.plot(sampled[:,0], sampled[:,1], '.')
plt.show()

# %%
# training
trainingdata = data.DataLoader(half_circle(n=1000), batch_size=64)

model = INN.Sequential(INN.BatchNorm1d(2), INN.Nonlinear(2, 'RealNVP'), INN.JacobianLinear(2),
                       INN.BatchNorm1d(2), INN.Nonlinear(2, 'RealNVP'), INN.JacobianLinear(2),
                       INN.BatchNorm1d(2), INN.Nonlinear(2, 'RealNVP'), INN.JacobianLinear(2),
                       INN.BatchNorm1d(2), INN.Nonlinear(2, 'RealNVP'), INN.JacobianLinear(2),
                       INN.BatchNorm1d(2), INN.Nonlinear(2, 'RealNVP'), INN.JacobianLinear(2), INN.ResizeFeatures(2, 1))

model.train()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# Prior distribution of output
p = INN.utilities.NormalDistribution()

loss_count = []
for i in range(50):
    losses = []
    for x in trainingdata:
        optimizer.zero_grad()
        y, logp, logdet = model(x)
        py = p.logp(y)

        loss = py + logp + logdet
        loss = -1 * loss.mean()

        loss.backward()
        losses.append(loss.item())
        optimizer.step()
    loss_count.append(np.mean(losses))
    print(sum(losses) / len(losses))
# Out:
# 0.7673046067357063
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <cell line: 17>:27                                                                            │
# │                                                                                                  │
# │ /usr/local/lib/python3.10/dist-packages/torch/_tensor.py:488 in backward                         │
# │                                                                                                  │
# │    485 │   │   │   │   create_graph=create_graph,                                                │
# │    486 │   │   │   │   inputs=inputs,                                                            │
# │    487 │   │   │   )                                                                             │
# │ ❱  488 │   │   torch.autograd.backward(                                                          │
# │    489 │   │   │   self, gradient, retain_graph, create_graph, inputs=inputs                     │
# │    490 │   │   )                                                                                 │
# │    491                                                                                           │
# │                                                                                                  │
# │ /usr/local/lib/python3.10/dist-packages/torch/autograd/__init__.py:197 in backward               │
# │                                                                                                  │
# │   194 │   # The reason we repeat same the comment below is that                                  │
# │   195 │   # some Python versions print out the first line of a multi-line function               │
# │   196 │   # calls in the traceback and some print out the last line                              │
# │ ❱ 197 │   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the bac   │
# │   198 │   │   tensors, grad_tensors_, retain_graph, create_graph, inputs,                        │
# │   199 │   │   allow_unreachable=True, accumulate_grad=True)  # Calls into the C++ engine to ru   │
# │   200                                                                                            │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# KeyboardInterrupt

# %%
# plot training results
inn_sampled = model.inverse(torch.randn(500, 1)).detach()

plt.plot(sampled[:,0], sampled[:,1], '.', label='sampled')
plt.plot(inn_sampled[:,0], inn_sampled[:,1], '.', label='INN sampled')
plt.legend()
plt.show()

# %%
plt.plot(loss_count, '.-')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.title('training loss record')
plt.show()
